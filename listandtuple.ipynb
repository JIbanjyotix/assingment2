# %%
list1 =[(2,5),(1,2),(4,4),(2,3),(2,1)]

list2=[]
list3=[]
for t in list1:
    list2.append(t[1],)
list2.sort()


for l in list2:
    for q in list1:
        if l ==int(q[1],):
            list3.append(q)
print(list3)
# Out:
# [(2, 1), (1, 2), (2, 3), (4, 4), (2, 5)]
